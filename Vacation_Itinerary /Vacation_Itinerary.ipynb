# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt


# Import API key
#from config import j_key

# Configure gmaps
#gmaps.configure(api_key=j_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    Unnamed: 0          City Country  Max Temp Current Description      Lat  \
# 0           0    Rio Grande      BR     70.00          light rain -32.0350
# 1           1       Rikitea      PF     78.73          light rain -23.1203
# 2           3  Vangaindrano      MG     71.24    scattered clouds -23.3500
# 3           4      Varadero      CU     77.00          few clouds  23.1536
# 4           5   Port Alfred      ZA     68.52       broken clouds -33.5906
#
#         Lng                  Hotel Name
# 0  -52.0986  Hotel Atlântico Rio Grande
# 1 -134.9692              Pension Maro'i
# 2   47.6000                Hotel Fanilo
# 3  -81.2514       Hotel Tuxpan Varadero
# 4   26.8910          The Halyards Hotel

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)


# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
brazil_df = vacation_df.loc[(vacation_df["Country"] == "BR")]
brazil_df.dropna()
# Out:
#      Unnamed: 0               City Country  Max Temp Current Description  \
# 0             0         Rio Grande      BR     70.00          light rain
# 17           39       Porto Walter      BR     73.27       broken clouds
# 41           97             Acarau      BR     76.12     overcast clouds
# 52          125               Unai      BR     70.14     overcast clouds
# 59          138             Castro      BR     65.08    scattered clouds
# 61          140    Arraial Do Cabo      BR     78.80           clear sky
# 66          158           Mongagua      BR     82.00           clear sky
# 85          196             Touros      BR     77.00       broken clouds
# 86          199              Soure      BR     74.66     overcast clouds
# 95          220            Itarema      BR     76.06     overcast clouds
# 96          221           Canarana      BR     73.35     overcast clouds
# 102         230           Belmonte      BR     78.80           clear sky
# 112         254          Bataipora      BR     79.65       broken clouds
# 118         264             Maceio      BR     75.20       broken clouds
# 120         267         Esmeraldas      BR     77.00           clear sky
# 123         270            Vacaria      BR     66.99          light rain
# 136         291            Mariana      BR     67.48     overcast clouds
# 137         292         Vila Velha      BR     77.00           clear sky
# 146         308           Cidreira      BR     68.52       moderate rain
# 148         316        Regeneracao      BR     72.32       broken clouds
# 155         329         Carutapera      BR     73.33     overcast clouds
# 172         363           Maragogi      BR     77.32     overcast clouds
# 179         381           Beberibe      BR     77.00       broken clouds
# 188         401      Joao Pinheiro      BR     68.90           clear sky
# 189         404      Alta Floresta      BR     73.90     overcast clouds
# 190         405  Sao Joao Da Barra      BR     76.44           clear sky
# 196         419            Camocim      BR     74.53       broken clouds
#
#          Lat      Lng                                Hotel Name
# 0   -32.0350 -52.0986                Hotel Atlântico Rio Grande
# 17   -8.2686 -72.7439                       Secretaria de saúde
# 41   -2.8856 -40.1200                          castelo pizzaria
# 52  -16.3575 -46.9061                             Hotel Regente
# 59  -24.7911 -50.0119                            CHACARA BAILLY
# 61  -22.9661 -42.0278                       Pousada Porto Praia
# 66  -24.0931 -46.6208                       Hostel Aloha Brasil
# 85   -5.1989 -35.4608                           INN NEW HORIZON
# 86   -0.7167 -48.5233                                   Casarão
# 95   -2.9248 -39.9167        Sea Lounge! Bar, Club & Restaurant
# 96  -11.6847 -41.7689                                     Hotel
# 102 -15.8631 -38.8828               Pousada Monte Carmelo O Pão
# 112 -22.2953 -53.2711                    Hotel Vale do Ivinhema
# 118  -9.6658 -35.7353                            Poutur Pousada
# 120 -19.7625 -44.3139                Forasteiro Pousada - Hotel
# 123 -28.5122 -50.9339                  Pampa Hotel - Vacaria/RS
# 136 -20.3778 -43.4161                MINAS POUSADA E HOTEL LTDA
# 137 -20.3297 -40.2925                 Quality Suites Vila Velha
# 146 -30.1811 -50.2056                             Hotel Castelo
# 148  -6.2378 -42.6883                             Hotel KANAYRA
# 155  -1.1950 -46.0200                                    Lidera
# 172  -9.0122 -35.2225  Salinas do Maragogi All Inclusive Resort
# 179  -4.1797 -38.1306           Villa Arte Pousada Morro Branco
# 188 -17.7425 -46.1725                              Hotel Santos
# 189  -9.8756 -56.0861                  Floresta Amazonica Hotel
# 190 -21.6403 -41.0511                   Pousada Porto De Canoas
# 196  -2.9022 -40.8411                        Hotel Ilha do Amor

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"] == "Arraial Do Cabo")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"] == "Sao Joao Da Barra")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"] == "Vila Velha")]
vacation_stop3 = vacation_df.loc[(vacation_df["City"] == "Mariana")]
vacation_end = vacation_df.loc[(vacation_df["City"] == "Arraial Do Cabo")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')

coords_stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
coords_stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
coords_stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Stop 1: {coords_stop1}, Stop 2: {coords_stop2}, Stop 3: {coords_stop3}')
# Out:
# Start: (-22.9661, -42.0278), End: (-22.9661, -42.0278)
# Stop 1: (-21.6403, -41.0511), Stop 2: (-20.3297, -40.2925), Stop 3: (-20.3778, -43.4161)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

import gmaps
import gmaps.datasets

# %%
fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[coords_stop1, coords_stop2, coords_stop3],
        travel_mode = "DRIVING")

fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
travel_plans = [vacation_start, vacation_stop1, vacation_stop2, vacation_stop3]
itinerary_df = pd.concat(travel_plans, sort=False)
itinerary_df
# Out:
#      Unnamed: 0               City Country  Max Temp Current Description  \
# 61          140    Arraial Do Cabo      BR     78.80           clear sky
# 190         405  Sao Joao Da Barra      BR     76.44           clear sky
# 137         292         Vila Velha      BR     77.00           clear sky
# 136         291            Mariana      BR     67.48     overcast clouds
#
#          Lat      Lng                  Hotel Name
# 61  -22.9661 -42.0278         Pousada Porto Praia
# 190 -21.6403 -41.0511     Pousada Porto De Canoas
# 137 -20.3297 -40.2925   Quality Suites Vila Velha
# 136 -20.3778 -43.4161  MINAS POUSADA E HOTEL LTDA

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
